# %%
import pandas as pd
jejudata=pd.read_excel('C:/Users/user/.jupyter/agedata.xlsx')
jejudata
# Out:
#                년월   시도명 지역구분 읍면동명  Unnamed: 4         업종명 이용자 구분 관광구분   연령대  \
# 0      2018-01-01  서귀포시   도심  색달동         NaN  차량용 가스 충전업    내국인   단체  30.0
# 1      2018-01-01  서귀포시   도심  색달동         NaN  차량용 가스 충전업    내국인   개별  20.0
# 2      2018-01-01  서귀포시   도심  상효동         NaN  차량용 가스 충전업   제주도민   도민  50.0
# 3      2018-01-01  서귀포시   도심  상효동         NaN  차량용 가스 충전업     법인   단체   NaN
# 4      2018-01-01  서귀포시   도심  상예동         NaN  차량용 가스 충전업   제주도민   도민  60.0
# ...           ...   ...  ...  ...         ...         ...    ...  ...   ...
# 497022 2018-12-01  서귀포시   읍면  성산읍         NaN    일반유흥 주점업   제주도민   도민  40.0
# 497023 2018-12-01  서귀포시   읍면  성산읍         NaN    일반유흥 주점업   제주도민   도민  40.0
# 497024 2018-12-01  서귀포시   읍면  성산읍         NaN    일반유흥 주점업   제주도민   도민  60.0
# 497025 2018-12-01  서귀포시   읍면  성산읍         NaN    일반유흥 주점업    내국인   단체  40.0
# 497026 2018-12-01  서귀포시   읍면  표선면         NaN    일반유흥 주점업   제주도민   도민  40.0
#
#           성별      이용금액  Unnamed: 11 업종명 대분류  Unnamed: 13
# ...

# %%
some=jejudata[(jejudata['이용자 구분']=="제주도민")]
            
del some["Unnamed:4"]
# Out:
#                년월   시도명 지역구분 읍면동명  Unnamed: 4         업종명 이용자 구분 관광구분   연령대  \
# 2      2018-01-01  서귀포시   도심  상효동         NaN  차량용 가스 충전업   제주도민   도민  50.0
# 4      2018-01-01  서귀포시   도심  상예동         NaN  차량용 가스 충전업   제주도민   도민  60.0
# 6      2018-01-01  서귀포시   도심  색달동         NaN  차량용 가스 충전업   제주도민   도민  20.0
# 8      2018-01-01  서귀포시   도심  법환동         NaN  차량용 가스 충전업   제주도민   도민  70.0
# 9      2018-01-01  서귀포시   도심  법환동         NaN  차량용 가스 충전업   제주도민   도민  60.0
# ...           ...   ...  ...  ...         ...         ...    ...  ...   ...
# 497020 2018-12-01  서귀포시   읍면  성산읍         NaN    일반유흥 주점업   제주도민   도민  70.0
# 497022 2018-12-01  서귀포시   읍면  성산읍         NaN    일반유흥 주점업   제주도민   도민  40.0
# 497023 2018-12-01  서귀포시   읍면  성산읍         NaN    일반유흥 주점업   제주도민   도민  40.0
# 497024 2018-12-01  서귀포시   읍면  성산읍         NaN    일반유흥 주점업   제주도민   도민  60.0
# 497026 2018-12-01  서귀포시   읍면  표선면         NaN    일반유흥 주점업   제주도민   도민  40.0
#
#         성별      이용금액  Unnamed: 11 업종명 대분류  Unnamed: 13
# ...
